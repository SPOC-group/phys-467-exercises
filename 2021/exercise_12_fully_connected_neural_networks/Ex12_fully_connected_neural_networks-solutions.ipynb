# %% [markdown]
# # PHYS-467 Machine Learning for Physisicst
# Fully Connected Networks - Solutions

# %% [markdown]
# *Exercise 1: Train a fully connected network on MNIST dataset using PyTorch. Plot the train loss and the train accuracy as a function of the number of epochs. Evaluate the generalization perfomances of the network by evaluating the test error.*

# %%
import numpy as np
import torch
from torchvision import transforms, datasets

# %%
# download MNIST dataset through torchvision PyTorch library (https://pytorch.org/vision/stable/index.html)

train = datasets.MNIST('', train=True, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize(0., 1.)]))
test = datasets.MNIST('', train=False, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize(0., 1.)]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting MNIST/raw/train-images-idx3-ubyte.gz to MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting MNIST/raw/train-labels-idx1-ubyte.gz to MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting MNIST/raw/t10k-images-idx3-ubyte.gz to MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting MNIST/raw/t10k-labels-idx1-ubyte.gz to MNIST/raw

# %%
from torch.utils.data import DataLoader

# %%
# create a Python iterable to prepare the dataset for training and testing through the torch.utils.data class (https://pytorch.org/docs/stable/data.html)

train_data_loader = DataLoader(train, batch_size=64, shuffle=True, num_workers=1)

test_data_loader = DataLoader(test, batch_size=64, shuffle=False, num_workers=1)

# %%
# extract the size of training and test set

trainset_shape = train_data_loader.dataset.data.shape
print("The training set has size: ", trainset_shape)

testset_shape = test_data_loader.dataset.data.shape
print("The test set has size: ", testset_shape)
# Out:
# The training set has size:  torch.Size([60000, 28, 28])
# The test set has size:  torch.Size([10000, 28, 28])

# %%
import torch.nn as nn
from torch import optim

# %%
def train_loop(train_data_loader, model, epochs = 1000, learning_rate = 0.01, optimizer = 'SGD', loss = 'CrossEntropy'):
  """
  This function trains a neural network with SGD and its variants.
  Input: train_data_loader = iterable over the training set;
         model = neural network architecture with weights and biases;
         learning_rate = size of gradient updates;
         optimizer = which variant of gradient descent algorithm to use;
         loss = loss function.
  Output: trained neural network model and metrics stored in *.csv file. 
  """

  # select which optimizer and which loss function to use
  if loss == 'CrossEntropy':
    l = torch.nn.CrossEntropyLoss()
  if optimizer == 'SGD':
    o = optim.SGD(model.parameters(), lr=learning_rate)

  # extract the size of the training set
  size = len(train_data_loader.dataset)

  # initialize an empty dictionary
  res = {'epoch': [], 'train_loss': [], 'train_accuracy': []}

  # loop over epochs
  for e in range(epochs):
    print(f"Epoch {e+1}\n-------------------------------")

    # initialize the variables for both train loss and accuracy  
    running_loss = 0
    running_accuracy = 0.
    # loop over all batches and over all input-output pair within a batch
    for batch, (X, y) in enumerate(train_data_loader): 

        o.zero_grad() # setting gradient to zeros       
        pred = model(X) # get predictions through forward pass
        loss = l(pred, y) # compute the loss
        
        
        loss.backward() # backward propagation        
        
        o.step() # update the gradient to new gradients

    # compute the metrics of interest
        running_loss += loss.item()
        dummy_pred = torch.argmax(pred, dim = 1) # the prediction corresponds to the index pointing to the maximum score
        running_accuracy += (dummy_pred == y).float().sum() # sum only over correct predictions

        # check how the training is evolving accross the batches
        if batch % 100 == 0:
            current = (batch + 1) * len(X)
            print(f"Processing batch n. {batch+1} ----> running loss: {running_loss/(batch + 1):>7f}, running accuracy: {running_accuracy/current:>7f} [{current:>5d}/{size:>5d}]")
    
    running_loss = running_loss/(batch + 1)
    running_accuracy = 100 * running_accuracy.numpy() / size
    print("")
    print("running training loss =  ", running_loss, " running training accuracy = ", running_accuracy)
    print("")

    res['epoch'].append(e) # populate the dictionary of results
    res['train_loss'].append(running_loss)
    res['train_accuracy'].append(running_accuracy)

  print("Done!")

  res = pd.DataFrame.from_dict(res) # translate the dictionary into a pandas dataframe
  res.to_csv("./metrics_over_epochs.csv", mode = 'w', index = False) # store the results into a *.csv file
  
  return

# %%
import pandas as pd

# %%
# define the neural network model
input_size = train_data_loader.dataset.data.shape[1] * train_data_loader.dataset.data.shape[2] # the MNIST is made of 28*28 pixel images. Therefore the input size of the input layer of a fully-connected network is 28*28 = 784
hidden_layers = [128,64] # number of hidden layers and hidden units
output_size = 10 # total number of classes = size of the output layer

# instantiate the sequential contrainer to stack the network layers (https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) through torch.nn (https://pytorch.org/docs/stable/nn.html)
model = nn.Sequential( 
    nn.Flatten(), # reshape the 28*28 matrix of pixels into an array of length 784 (https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html)
    nn.Linear(input_size, hidden_layers[0]),
    nn.ReLU(),
    nn.Linear(hidden_layers[0], hidden_layers[1]),
    nn.ReLU(),
    nn.Linear(hidden_layers[1], output_size)
)

# define the hyper-parameters of the network training
epochs = 10
learning_rate = 0.01
optimizer = 'SGD'
loss = 'CrossEntropy'

# train the network
train_loop(train_data_loader, model, epochs = epochs, learning_rate = learning_rate, optimizer = optimizer, loss = loss)
# Out:
# Epoch 1
# -------------------------------
# Processing batch n. 1 ----> running loss: 2.298220, running accuracy: 0.156250 [   64/60000]
# Processing batch n. 101 ----> running loss: 2.295214, running accuracy: 0.142327 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 2.280086, running accuracy: 0.195740 [12864/60000]
# Processing batch n. 301 ----> running loss: 2.259090, running accuracy: 0.274242 [19264/60000]
# Processing batch n. 401 ----> running loss: 2.228885, running accuracy: 0.334983 [25664/60000]
# Processing batch n. 501 ----> running loss: 2.185101, running accuracy: 0.383327 [32064/60000]
# Processing batch n. 601 ----> running loss: 2.119519, running accuracy: 0.423669 [38464/60000]
# Processing batch n. 701 ----> running loss: 2.030637, running accuracy: 0.461818 [44864/60000]
# Processing batch n. 801 ----> running loss: 1.929590, running accuracy: 0.496294 [51264/60000]
# Processing batch n. 901 ----> running loss: 1.828594, running accuracy: 0.525770 [57664/60000]
#
# running training loss =   1.7930706409630237  running training accuracy =  53.553333333333335
#
# Epoch 2
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.922347, running accuracy: 0.750000 [   64/60000]
# Processing batch n. 101 ----> running loss: 0.831729, running accuracy: 0.791460 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 0.779652, running accuracy: 0.800529 [12864/60000]
# Processing batch n. 301 ----> running loss: 0.741810, running accuracy: 0.810475 [19264/60000]
# Processing batch n. 401 ----> running loss: 0.705188, running accuracy: 0.818072 [25664/60000]
# Processing batch n. 501 ----> running loss: 0.681292, running accuracy: 0.822605 [32064/60000]
# Processing batch n. 601 ----> running loss: 0.661691, running accuracy: 0.826175 [38464/60000]
# Processing batch n. 701 ----> running loss: 0.640986, running accuracy: 0.830599 [44864/60000]
# Processing batch n. 801 ----> running loss: 0.622171, running accuracy: 0.835167 [51264/60000]
# Processing batch n. 901 ----> running loss: 0.606502, running accuracy: 0.839310 [57664/60000]
#
# running training loss =   0.600229612831622  running training accuracy =  84.06
#
# Epoch 3
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.481657, running accuracy: 0.890625 [   64/60000]
# Processing batch n. 101 ----> running loss: 0.463403, running accuracy: 0.875464 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 0.451073, running accuracy: 0.875389 [12864/60000]
# Processing batch n. 301 ----> running loss: 0.445627, running accuracy: 0.876142 [19264/60000]
# Processing batch n. 401 ----> running loss: 0.441654, running accuracy: 0.877767 [25664/60000]
# Processing batch n. 501 ----> running loss: 0.434256, running accuracy: 0.879242 [32064/60000]
# Processing batch n. 601 ----> running loss: 0.426608, running accuracy: 0.880382 [38464/60000]
# Processing batch n. 701 ----> running loss: 0.421730, running accuracy: 0.881308 [44864/60000]
# Processing batch n. 801 ----> running loss: 0.418516, running accuracy: 0.882296 [51264/60000]
# Processing batch n. 901 ----> running loss: 0.414345, running accuracy: 0.883411 [57664/60000]
#
# running training loss =   0.41273879992173934  running training accuracy =  88.39666666666666
#
# Epoch 4
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.263568, running accuracy: 0.921875 [   64/60000]
# Processing batch n. 101 ----> running loss: 0.360476, running accuracy: 0.896349 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 0.367068, running accuracy: 0.895756 [12864/60000]
# Processing batch n. 301 ----> running loss: 0.364125, running accuracy: 0.896802 [19264/60000]
# Processing batch n. 401 ----> running loss: 0.361908, running accuracy: 0.898496 [25664/60000]
# Processing batch n. 501 ----> running loss: 0.362956, running accuracy: 0.898172 [32064/60000]
# Processing batch n. 601 ----> running loss: 0.362726, running accuracy: 0.897723 [38464/60000]
# Processing batch n. 701 ----> running loss: 0.363293, running accuracy: 0.897401 [44864/60000]
# Processing batch n. 801 ----> running loss: 0.360986, running accuracy: 0.897589 [51264/60000]
# Processing batch n. 901 ----> running loss: 0.358655, running accuracy: 0.898169 [57664/60000]
#
# running training loss =   0.35754542441160947  running training accuracy =  89.84
#
# Epoch 5
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.314473, running accuracy: 0.921875 [   64/60000]
# Processing batch n. 101 ----> running loss: 0.336992, running accuracy: 0.906869 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 0.337358, running accuracy: 0.905084 [12864/60000]
# Processing batch n. 301 ----> running loss: 0.333977, running accuracy: 0.904952 [19264/60000]
# Processing batch n. 401 ----> running loss: 0.331077, running accuracy: 0.905003 [25664/60000]
# Processing batch n. 501 ----> running loss: 0.330425, running accuracy: 0.905252 [32064/60000]
# Processing batch n. 601 ----> running loss: 0.329566, running accuracy: 0.905106 [38464/60000]
# Processing batch n. 701 ----> running loss: 0.328719, running accuracy: 0.905760 [44864/60000]
# Processing batch n. 801 ----> running loss: 0.329495, running accuracy: 0.905392 [51264/60000]
# Processing batch n. 901 ----> running loss: 0.328562, running accuracy: 0.905938 [57664/60000]
#
# running training loss =   0.32623720436351006  running training accuracy =  90.65666666666667
#
# Epoch 6
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.191765, running accuracy: 0.953125 [   64/60000]
# Processing batch n. 101 ----> running loss: 0.313976, running accuracy: 0.911046 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 0.317319, running accuracy: 0.909670 [12864/60000]
# Processing batch n. 301 ----> running loss: 0.313532, running accuracy: 0.910610 [19264/60000]
# Processing batch n. 401 ----> running loss: 0.307500, running accuracy: 0.911588 [25664/60000]
# Processing batch n. 501 ----> running loss: 0.306691, running accuracy: 0.912675 [32064/60000]
# Processing batch n. 601 ----> running loss: 0.305121, running accuracy: 0.913244 [38464/60000]
# Processing batch n. 701 ----> running loss: 0.304414, running accuracy: 0.913695 [44864/60000]
# Processing batch n. 801 ----> running loss: 0.305181, running accuracy: 0.913351 [51264/60000]
# Processing batch n. 901 ----> running loss: 0.303926, running accuracy: 0.913655 [57664/60000]
#
# running training loss =   0.3030103864207832  running training accuracy =  91.37833333333333
#
# Epoch 7
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.171171, running accuracy: 0.953125 [   64/60000]
# Processing batch n. 101 ----> running loss: 0.289763, running accuracy: 0.916460 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 0.291097, running accuracy: 0.916356 [12864/60000]
# Processing batch n. 301 ----> running loss: 0.285592, running accuracy: 0.919072 [19264/60000]
# Processing batch n. 401 ----> running loss: 0.282981, running accuracy: 0.919420 [25664/60000]
# Processing batch n. 501 ----> running loss: 0.285125, running accuracy: 0.918819 [32064/60000]
# Processing batch n. 601 ----> running loss: 0.284917, running accuracy: 0.919041 [38464/60000]
# Processing batch n. 701 ----> running loss: 0.283191, running accuracy: 0.919312 [44864/60000]
# Processing batch n. 801 ----> running loss: 0.284341, running accuracy: 0.918422 [51264/60000]
# Processing batch n. 901 ----> running loss: 0.284079, running accuracy: 0.918407 [57664/60000]
#
# running training loss =   0.28351341878204966  running training accuracy =  91.85666666666667
#
# Epoch 8
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.396355, running accuracy: 0.890625 [   64/60000]
# Processing batch n. 101 ----> running loss: 0.276150, running accuracy: 0.918936 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 0.274576, running accuracy: 0.919077 [12864/60000]
# Processing batch n. 301 ----> running loss: 0.272579, running accuracy: 0.920681 [19264/60000]
# Processing batch n. 401 ----> running loss: 0.275982, running accuracy: 0.919888 [25664/60000]
# Processing batch n. 501 ----> running loss: 0.271696, running accuracy: 0.921376 [32064/60000]
# Processing batch n. 601 ----> running loss: 0.271483, running accuracy: 0.922187 [38464/60000]
# Processing batch n. 701 ----> running loss: 0.267856, running accuracy: 0.923435 [44864/60000]
# Processing batch n. 801 ----> running loss: 0.267314, running accuracy: 0.923377 [51264/60000]
# Processing batch n. 901 ----> running loss: 0.265897, running accuracy: 0.923921 [57664/60000]
#
# running training loss =   0.2656198455723745  running training accuracy =  92.405
#
# Epoch 9
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.248141, running accuracy: 0.937500 [   64/60000]
# Processing batch n. 101 ----> running loss: 0.251952, running accuracy: 0.931467 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 0.256622, running accuracy: 0.927938 [12864/60000]
# Processing batch n. 301 ----> running loss: 0.255135, running accuracy: 0.929558 [19264/60000]
# Processing batch n. 401 ----> running loss: 0.255520, running accuracy: 0.928421 [25664/60000]
# Processing batch n. 501 ----> running loss: 0.257288, running accuracy: 0.927582 [32064/60000]
# Processing batch n. 601 ----> running loss: 0.253868, running accuracy: 0.928427 [38464/60000]
# Processing batch n. 701 ----> running loss: 0.252162, running accuracy: 0.928785 [44864/60000]
# Processing batch n. 801 ----> running loss: 0.250566, running accuracy: 0.928663 [51264/60000]
# Processing batch n. 901 ----> running loss: 0.249764, running accuracy: 0.928517 [57664/60000]
#
# running training loss =   0.24941336961665642  running training accuracy =  92.865
#
# Epoch 10
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.218570, running accuracy: 0.906250 [   64/60000]
# Processing batch n. 101 ----> running loss: 0.239630, running accuracy: 0.935953 [ 6464/60000]
# Processing batch n. 201 ----> running loss: 0.239390, running accuracy: 0.932680 [12864/60000]
# Processing batch n. 301 ----> running loss: 0.242072, running accuracy: 0.931946 [19264/60000]
# Processing batch n. 401 ----> running loss: 0.245709, running accuracy: 0.930525 [25664/60000]
# Processing batch n. 501 ----> running loss: 0.243605, running accuracy: 0.930576 [32064/60000]
# Processing batch n. 601 ----> running loss: 0.241365, running accuracy: 0.930870 [38464/60000]
# Processing batch n. 701 ----> running loss: 0.237094, running accuracy: 0.931838 [44864/60000]
# Processing batch n. 801 ----> running loss: 0.236076, running accuracy: 0.932331 [51264/60000]
# Processing batch n. 901 ----> running loss: 0.234697, running accuracy: 0.932835 [57664/60000]
#
# running training loss =   0.2345067923312693  running training accuracy =  93.275
#
# Done!

# %%
# extract the weights and biases of the network 
for p in model.parameters():
  print(p)
# Out:
# Parameter containing:
# tensor([[-0.0041,  0.0340,  0.0011,  ...,  0.0020,  0.0299,  0.0314],
#         [-0.0230, -0.0248,  0.0084,  ..., -0.0356,  0.0120, -0.0317],
#         [-0.0250, -0.0117,  0.0179,  ...,  0.0276,  0.0091,  0.0091],
#         ...,
#         [-0.0217,  0.0135,  0.0325,  ...,  0.0082,  0.0274, -0.0202],
#         [ 0.0196,  0.0207, -0.0287,  ...,  0.0078, -0.0028,  0.0347],
#         [-0.0286, -0.0224,  0.0249,  ..., -0.0219, -0.0010, -0.0079]],
#        requires_grad=True)
# Parameter containing:
# tensor([-1.2594e-02,  2.1667e-02,  7.2027e-02,  3.0239e-02,  4.8572e-02,
#          6.3971e-02,  9.5801e-03,  2.0117e-02,  1.2936e-02,  6.4557e-02,
#         -3.8052e-03, -7.5441e-02, -1.8939e-02,  1.2900e-02,  4.6996e-02,
#          9.6456e-02, -8.8260e-04,  2.2381e-03, -1.8050e-02,  1.1277e-02,
#          5.0669e-02, -1.3371e-02,  1.2870e-02,  3.2889e-02,  3.2006e-02,
#          4.6753e-02,  1.0663e-01,  2.1469e-02,  2.8647e-02, -1.2312e-02,
#          2.0544e-02,  4.0539e-02,  1.0789e-01,  8.9894e-02,  1.2824e-01,
#          2.3191e-02, -2.6587e-05, -1.1416e-02,  1.7426e-02,  8.5699e-03,
#         -4.6364e-03, -7.9132e-03,  6.6533e-02,  6.8747e-03,  2.1301e-02,
#          2.7665e-03, -3.6564e-02,  4.9290e-02,  2.8543e-02, -3.9725e-02,
#          5.4318e-02,  7.5476e-02,  3.7158e-02,  2.5633e-02,  4.3688e-02,
#          3.6923e-02,  3.7624e-02,  5.1031e-02, -1.7996e-02,  4.8065e-02,
#          8.1603e-02,  2.0930e-02,  4.6123e-02, -8.2245e-02,  5.1088e-02,
#          6.1031e-02, -5.2208e-03,  7.8359e-03,  3.2134e-02, -2.2947e-02,
#         -2.6622e-02,  5.4626e-02,  1.3763e-02,  2.6755e-02,  2.2576e-02,
#         -1.0602e-02, -2.6973e-02,  1.9803e-02, -2.9182e-02, -8.7344e-03,
#          4.2374e-02,  2.9242e-02,  1.2834e-02,  4.6107e-02,  2.9211e-02,
#          7.6653e-02,  3.8595e-02,  2.1594e-04,  6.8047e-02, -1.1053e-02,
#          5.1017e-02,  1.9635e-02,  1.1861e-01,  9.9934e-03,  2.8270e-02,
#         -1.5850e-02,  5.4004e-02,  2.9965e-02,  3.1875e-02, -2.9362e-02,
#         -1.9502e-02, -1.3909e-02, -1.4501e-02, -1.0114e-01,  3.6201e-02,
#         -9.5954e-03,  4.9638e-02,  2.6154e-02,  5.9711e-02,  6.1459e-02,
#         -1.1926e-03,  1.9114e-02,  3.5292e-02,  3.1873e-03,  4.7997e-02,
#          2.9125e-02,  1.4647e-02, -9.9339e-03,  1.2891e-03,  1.0552e-01,
#          8.3091e-03,  6.1949e-02, -2.3494e-02, -2.5574e-03, -9.5383e-04,
#          7.0681e-02,  1.8928e-02,  6.5476e-02], requires_grad=True)
# Parameter containing:
# tensor([[-0.0518, -0.0575,  0.0034,  ...,  0.0052, -0.0787, -0.0013],
#         [-0.0144, -0.0305,  0.0488,  ...,  0.0874, -0.0555,  0.0823],
#         [ 0.0120,  0.0316, -0.0321,  ...,  0.0926,  0.0658, -0.0629],
#         ...,
#         [-0.0109, -0.0358, -0.0801,  ..., -0.0682, -0.0829, -0.0787],
#         [-0.0032,  0.0724,  0.1330,  ..., -0.1524, -0.0033,  0.0276],
#         [-0.0635, -0.0063, -0.0432,  ..., -0.0136,  0.0359,  0.0701]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.0581,  0.0246, -0.0009,  0.0147,  0.0564,  0.0378,  0.0995, -0.0357,
#          0.0915,  0.0923,  0.1272, -0.0069, -0.0089,  0.0214,  0.0115,  0.0606,
#          0.0470,  0.1472,  0.1687,  0.0044, -0.0167, -0.0780, -0.1073,  0.1703,
#          0.0684,  0.0243, -0.0658, -0.0211, -0.0327, -0.0145, -0.0442,  0.2011,
#         -0.1054, -0.0580, -0.0412, -0.0783,  0.0133, -0.0434, -0.0727,  0.0155,
#         -0.0336,  0.0392, -0.0281,  0.1119,  0.0962,  0.0514,  0.0232,  0.0729,
#          0.0397, -0.0127,  0.2910, -0.0154, -0.0491, -0.0076, -0.0328,  0.0315,
#          0.0931,  0.0505,  0.2294, -0.0732, -0.0473, -0.0538,  0.0418,  0.0012],
#        requires_grad=True)
# Parameter containing:
# tensor([[ 6.1542e-02,  3.1499e-03, -4.7913e-02,  3.3028e-02, -3.0134e-01,
#          -1.9909e-02, -6.0028e-03, -5.3346e-02, -2.4687e-01,  3.2930e-01,
#          -2.3818e-01, -7.9304e-02, -4.9860e-02, -2.1800e-01, -6.0828e-02,
#          -1.0758e-01, -9.0153e-02, -3.9603e-01, -3.2434e-01, -1.0463e-01,
#          -1.9956e-01, -1.2095e-01,  8.2627e-02, -2.2738e-01,  5.2591e-01,
#           1.0730e-01, -1.6672e-01,  3.0253e-02,  1.0313e-01,  3.3723e-02,
#           1.0023e-01,  1.6777e-01,  1.8058e-02,  2.5558e-01, -6.8805e-02,
#           2.4712e-01,  2.2887e-01, -1.2463e-02,  6.3420e-02,  3.5575e-02,
#           3.1827e-02,  8.6298e-02, -8.1891e-02, -1.6432e-01,  2.3614e-01,
#          -1.7757e-01, -2.1982e-01,  2.6127e-01,  4.5921e-02,  1.0263e-01,
#          -3.0718e-01,  4.1411e-01,  1.1888e-01,  2.4671e-02, -8.5508e-03,
#           1.0003e-01, -6.7239e-04,  4.0061e-01,  7.9687e-04, -3.0275e-02,
#          -6.7819e-02,  6.5164e-02, -1.8453e-01,  2.5055e-01],
#         [-4.2359e-02,  3.0733e-02, -1.2365e-01,  4.3234e-02,  2.3907e-01,
#          -1.4357e-01,  3.0595e-01, -4.8181e-02,  2.1590e-01, -4.8009e-01,
#           4.2456e-02, -2.5794e-01, -1.4214e-02,  1.4421e-01, -3.6931e-02,
#          -6.3028e-02, -1.0763e-01,  4.4205e-02,  2.0945e-01, -1.9481e-01,
#           2.2498e-02,  7.7666e-03, -1.5511e-01,  1.4137e-01, -1.3571e-01,
#          -5.2100e-02,  3.0879e-01, -3.4421e-01,  1.2360e-01,  9.9089e-02,
#           8.0072e-02,  2.4665e-02, -6.8621e-02, -4.3286e-02, -2.7750e-02,
#          -2.8028e-01, -2.3492e-01,  4.1220e-01, -1.6134e-02, -3.9914e-01,
#          -1.6992e-01,  1.1909e-01,  1.6845e-01,  2.9640e-01, -5.7757e-01,
#          -2.9723e-01,  2.3995e-01,  4.4898e-02,  9.3291e-02,  1.8558e-01,
#           3.9471e-01, -2.8171e-01,  6.5707e-02, -9.4751e-02,  3.4566e-01,
#           9.8501e-02,  9.8921e-02, -1.0574e-01,  1.7506e-01, -2.0606e-02,
#           2.2797e-01, -4.7912e-02, -4.4784e-02, -9.9160e-03],
#         [ 1.1223e-02,  1.4659e-02,  1.2741e-01,  2.5830e-02,  6.2093e-02,
#           4.1032e-01,  1.1585e-01, -2.5068e-01,  2.3163e-01,  1.1297e-01,
#           3.0804e-01, -7.0981e-02,  3.8436e-03,  1.1955e-01,  1.7502e-01,
#          -1.5462e-01,  1.0213e-02,  2.6801e-01,  2.2441e-02, -2.7185e-01,
#           2.9685e-01, -7.1503e-02,  2.5676e-01,  1.4553e-01, -1.7735e-01,
#          -1.0981e-01,  3.3136e-01, -6.0528e-02, -7.1622e-02,  1.9025e-03,
#           5.9678e-02, -1.7571e-01, -1.4031e-01,  4.0877e-01, -1.2081e-01,
#           3.5357e-01,  7.8707e-03, -1.4393e-01,  8.7420e-02, -1.7904e-02,
#           2.4523e-01,  1.2311e-01, -3.0923e-01,  1.1603e-01,  2.8023e-01,
#          -7.2094e-01,  3.1575e-02,  1.0106e-01, -6.0512e-03, -4.6023e-02,
#          -5.9126e-02,  4.7397e-01,  1.3778e-02, -5.0376e-02,  7.8442e-02,
#           9.0861e-04, -8.6110e-02, -1.6851e-01,  2.7684e-01, -1.5020e-02,
#          -9.9214e-02, -1.9322e-02, -2.0382e-01, -7.8072e-02],
#         [ 1.5012e-01,  7.6553e-02, -9.0588e-02, -6.9103e-02, -2.2620e-01,
#          -3.9183e-02, -3.0402e-01, -4.7451e-02,  5.1179e-01, -2.5463e-01,
#          -6.6890e-02,  2.7327e-01, -2.0603e-01,  7.1631e-02, -3.2942e-02,
#           2.4691e-01, -9.2159e-03, -1.9107e-01,  5.6019e-01, -6.7187e-02,
#           3.0219e-02,  3.0610e-03,  1.3820e-01, -2.5565e-02, -2.8391e-01,
#          -1.3835e-01, -1.0634e-01,  2.7066e-01,  5.8681e-02,  4.2243e-02,
#           6.4878e-02,  3.4451e-01,  1.5814e-01,  1.3563e-01, -6.6716e-03,
#           3.5330e-01, -2.9089e-01,  2.6435e-01, -1.2266e-01, -1.6837e-01,
#          -1.1579e-01, -1.0661e-01, -3.7198e-02, -3.5059e-01, -9.6232e-02,
#          -2.0036e-01,  1.8112e-01, -2.1037e-01, -1.8623e-03, -2.1751e-01,
#          -3.6471e-03,  1.9971e-01, -1.1493e-01,  9.3827e-02, -1.4686e-01,
#          -3.7146e-02,  1.1118e-01,  1.4299e-01, -2.0233e-02, -8.2511e-02,
#          -1.6744e-01, -5.5490e-03,  2.8470e-01, -3.1593e-01],
#         [-1.3702e-01,  9.0324e-03,  2.6189e-01, -6.2521e-02,  4.9139e-01,
#          -3.2419e-01,  3.1621e-02, -9.8631e-03, -3.7959e-01,  3.2330e-02,
#           1.5166e-01,  1.4389e-01,  3.2958e-01,  3.8530e-02,  2.1831e-01,
#           4.5398e-02, -3.6869e-02,  4.2815e-01,  1.2024e-01,  5.6994e-03,
#           1.5241e-03,  6.7582e-02,  2.3296e-01, -7.9766e-02,  7.6726e-04,
#          -2.0205e-01, -3.4305e-01, -2.4631e-01,  1.2204e-01, -5.6989e-02,
#           9.6267e-02, -4.5509e-01,  1.2850e-01, -2.0553e-01,  1.4700e-02,
#          -2.9186e-01,  2.4590e-01, -1.1263e-01,  6.6554e-02,  2.6756e-01,
#          -3.3966e-01,  2.8714e-02,  1.5290e-01,  2.3145e-01,  5.1787e-02,
#           4.9762e-01, -9.7992e-02, -1.6907e-01, -2.9470e-01, -3.5596e-01,
#          -1.6679e-01,  8.3251e-02, -7.1741e-02,  2.0560e-02, -5.1477e-01,
#           1.2141e-01,  2.0847e-01, -1.4105e-01, -1.1729e-01, -5.0752e-02,
#           5.9215e-02,  9.5927e-02, -6.2687e-03,  6.7316e-02],
#         [ 8.8830e-02, -2.0446e-02,  3.6019e-02, -4.6046e-02,  4.7599e-02,
#          -4.3615e-01, -1.6736e-01, -4.6380e-02,  1.1511e-01, -8.1259e-02,
#          -7.4145e-02,  1.6123e-01,  2.6749e-03,  1.1087e-02,  1.0288e-01,
#          -1.8459e-02, -4.1929e-02,  1.6948e-01,  3.2188e-01, -8.9739e-02,
#          -2.8582e-01, -1.2031e-03, -2.8056e-01, -2.0869e-01,  2.4602e-02,
#           3.1330e-01, -2.6908e-01, -1.6025e-01, -6.0334e-02, -9.6431e-03,
#           1.2019e-01,  7.5665e-01, -1.8207e-01, -2.9236e-01,  7.5156e-02,
#           1.7036e-01,  6.7579e-02, -1.6218e-01,  4.7876e-03,  1.0355e-01,
#           3.3469e-01, -7.8950e-02,  3.1856e-02,  3.3864e-02, -1.0199e-01,
#           3.6896e-01, -4.5137e-02,  1.8346e-01,  1.7147e-02, -1.4791e-01,
#           3.2094e-01, -2.9842e-01, -3.3194e-02,  5.9017e-02, -1.4490e-01,
#          -5.3704e-02, -2.6603e-01,  3.9280e-01,  3.7786e-01,  1.0018e-01,
#           2.2478e-02,  5.0788e-03, -5.0758e-01,  5.5248e-03],
#         [ 1.2511e-01, -1.0065e-01, -1.8017e-01,  1.1239e-01, -2.9073e-01,
#           1.0979e-01,  2.6054e-01, -1.4492e-01, -2.6464e-01, -1.7526e-02,
#          -2.6888e-01, -2.0649e-01,  5.0329e-01,  5.5971e-01, -6.6756e-02,
#          -2.3250e-01,  9.8927e-02,  3.1171e-02, -3.2545e-01, -2.3826e-01,
#          -1.9136e-01, -1.0448e-02, -1.1358e-01, -1.2416e-03,  7.4039e-02,
#          -1.4027e-01, -2.7738e-01, -1.2224e-01, -1.2174e-01,  4.9521e-03,
#          -2.0259e-02, -3.0705e-01,  9.6885e-02, -3.1472e-01, -7.5981e-02,
#           1.8293e-01,  2.6308e-01, -3.9611e-02, -6.2080e-02,  3.3905e-01,
#          -2.0484e-01, -5.1595e-02, -2.5830e-01,  4.1469e-01, -1.0751e-01,
#           1.5227e-01, -2.8353e-02, -7.9803e-02,  3.4277e-01, -1.3760e-01,
#          -2.8424e-01, -5.0014e-03, -1.1267e-01,  9.9092e-02,  2.1140e-01,
#          -1.1367e-01,  2.9161e-02, -1.3298e-01,  3.8612e-01,  4.5523e-02,
#          -1.1288e-01,  1.1255e-01, -2.0815e-01,  3.2607e-02],
#         [ 7.0517e-02,  1.9688e-02,  2.6639e-02, -1.2251e-01, -1.4528e-01,
#           4.7465e-01,  1.8453e-01,  2.6020e-01, -4.0277e-01,  3.5545e-01,
#           1.2650e-01, -4.0875e-01, -4.4200e-01, -2.4732e-01,  1.3644e-01,
#           2.5960e-02, -5.0417e-02, -2.7128e-01, -1.2619e-01, -1.2836e-01,
#           2.1432e-01,  8.2657e-02,  9.2468e-02,  4.8177e-01, -1.8125e-01,
#          -2.4314e-01,  5.4807e-03, -2.0627e-01, -5.6738e-03, -1.6860e-03,
#          -5.1645e-03,  1.7183e-01, -3.4194e-02,  1.9289e-01,  6.8155e-02,
#          -4.7300e-01, -1.9821e-01, -1.2135e-01, -2.7648e-04,  1.4584e-01,
#           1.4335e-01, -2.4846e-02,  2.5665e-01,  3.5934e-02,  1.8491e-01,
#           5.5563e-02, -5.9306e-02,  2.9540e-02, -7.2437e-03,  3.7980e-01,
#           4.3597e-01,  7.9626e-02, -1.1713e-01, -3.5316e-02, -3.1178e-01,
#           9.6698e-02,  2.3880e-01, -8.9960e-02, -1.1158e-01,  9.1699e-02,
#           1.2615e-01, -3.2504e-02,  4.4232e-01, -7.1745e-03],
#         [-1.1318e-01, -7.5842e-02,  6.3260e-02,  4.1634e-02,  1.9719e-01,
#          -2.2452e-01,  3.4173e-02,  3.7251e-01,  1.7568e-01,  3.6767e-02,
#          -2.5083e-01,  1.6131e-01, -4.6356e-03, -1.6990e-01, -1.1003e-01,
#           9.9401e-02,  1.0103e-01, -1.2385e-01, -1.7449e-01,  2.4636e-01,
#          -1.5135e-01, -5.7901e-02,  2.4453e-01, -2.7875e-01, -3.3981e-01,
#           3.7556e-01,  4.7021e-01,  7.1079e-02, -1.0935e-01,  3.2030e-02,
#           9.4978e-02, -8.2146e-02, -4.0083e-03,  8.3481e-02, -1.1284e-01,
#           1.3325e-03,  2.2524e-01,  1.1394e-01, -1.0412e-01,  7.4041e-02,
#           5.7903e-02,  2.1074e-02,  2.6000e-01,  6.7264e-02,  5.7992e-02,
#           1.9448e-01,  3.0275e-01, -5.7993e-02,  1.8601e-01,  1.9298e-01,
#          -3.2697e-01, -2.3568e-01, -4.4633e-02, -5.1105e-02,  3.3898e-01,
#           1.9821e-02, -3.7786e-01, -2.0274e-01, -3.3586e-01,  5.8630e-02,
#          -1.2701e-02,  1.0900e-01, -2.3969e-01, -9.6317e-02],
#         [-6.0707e-02, -9.6716e-02, -1.6267e-01,  7.9236e-02,  3.6073e-01,
#           2.0913e-01, -9.4324e-02, -8.7674e-02, -9.9087e-02,  2.6086e-01,
#           6.2981e-02,  2.5309e-01,  1.0865e-01, -2.1115e-01, -2.1632e-01,
#           2.7759e-01, -3.2284e-02, -5.2881e-02, -1.5082e-01,  4.9021e-01,
#           3.6938e-01,  5.0700e-02, -2.4964e-01, -5.6253e-02,  5.8679e-02,
#           2.4324e-01, -2.1954e-01,  1.8288e-01, -6.2065e-04,  1.1441e-01,
#          -6.3936e-02, -2.8396e-01,  4.2173e-02, -3.4775e-02, -5.2383e-02,
#          -4.3790e-02, -2.6782e-01, -8.6470e-03, -4.6496e-02,  1.4584e-01,
#          -1.9220e-01, -4.7988e-02, -7.3791e-02, -3.5934e-01, -9.6446e-02,
#           2.8421e-01, -1.8234e-01,  2.7639e-01, -1.2122e-01, -6.7648e-02,
#           1.6804e-02, -3.1088e-01,  1.0352e-01, -4.1309e-02, -1.6172e-01,
#           8.1733e-02,  1.1854e-01, -2.8741e-01, -4.1737e-01, -9.3929e-02,
#           1.0367e-03, -3.5659e-02,  3.9589e-01, -1.0117e-01]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.0047,  0.0841, -0.0765,  0.1185,  0.0471,  0.3483,  0.0052,  0.1500,
#         -0.3192, -0.0908], requires_grad=True)

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
# plot the train loss as a function of the number of epochs

fig, ax = plt.subplots(figsize=(10,7)) # initialize an empty figure and axes object
res = pd.read_csv("./metrics_over_epochs.csv") # read the content of the *.csv file

res.plot(x='epoch',
         y='train_loss',
         color = 'blue',
         lw = 3, # linewidth
         ax=ax) # plot the results with matplotlib through pandas

ax.set_title("train loss function versus number of epochs") # set the plot title
ax.set_ylabel("train loss") # set the name of the y axis
ax.set_xlabel("epoch") # set the name of the x axis
ax.set_xlim(-1, 10)
# Out:
# (-1.0, 10.0)

# %%
# plot the train accuracy as a function of the number of epochs

fig, ax = plt.subplots(figsize=(10,7)) # initialize an empty figure and axes object
res = pd.read_csv("./metrics_over_epochs.csv") # read the content of the *.csv file

res.plot(x='epoch',
         y='train_accuracy',
         color = 'red',
         lw = 3, # linewidth
         ax=ax) # plot the results with matplotlib through pandas

ax.set_title("train accuracy versus number of epochs") # set the plot title
ax.set_ylabel("train accuracy") # set the name of the y axis
ax.set_xlabel("epoch") # set the name of the x axis
ax.set_xlim(-1, 10)
# Out:
# (-1.0, 10.0)

# %%
def check_mistakes_last_batch(X, y, dummy_pred):
  """
  This function checks the mistakes the network does on the last batch of the test set. 
  Input: (X,y) = last batch of examples;
         dummy_pred = prediction of the network in dummy format.
  Output: check whether there are mistakes, and if there are plot the image corresponding to the mistake done by the network with its own label and the network prediction 
  """

  mistakes = dummy_pred.numpy() != y.numpy() # detect the mistakes
  Xm = X[mistakes].numpy() # select only those examples for which the network makes a mistake
  ym = y[mistakes].numpy()
  dummy_predm = dummy_pred[mistakes].numpy()
  n_mistakes = len(np.where(mistakes)[0]) # count the number of mistakes

  print(f'{n_mistakes} mistakes in last batch')

  if n_mistakes == 0: # if there are no mistakes return
    print("No mistakes in the last batch")
  else: # if there are mistakes plot the images corresponding to the mistake, together with its label and the corresponding network prediction            
    for i in range(n_mistakes):  
      plt.subplot(3, 3,  i + 1) # create the plot container
      plt.imshow(Xm[i][0], cmap=plt.get_cmap('gray')) # plot the image
      plt.tight_layout(pad = 0.3) # add space between subplots
      plt.title("y = " + str(ym[i]) + " " + "pred = " + str(dummy_predm[i]), color = 'red') # print labels and predictions as a title of the plot
      plt.show()
  return

# %%
def test_loop(test_data_loader, model, loss = 'CrossEntropy'):

  # initialize the variables for both test loss and accuracy 
  test_loss = 0.
  test_accuracy = 0.
  
  # select which loss function to use
  if loss == 'CrossEntropy':
    l = torch.nn.CrossEntropyLoss()

  # extract the size of the test set
  size = len(test_data_loader.dataset)

  # create the container to avoid gradient computation
  with torch.no_grad():
    # loop over all test input-output pairs
    for X, y in test_data_loader: 
        
        pred = model(X) # get predictions through forward pass
        loss = l(pred, y) # compute the loss
        
    # compute the metrics of interest    
        test_loss += loss.item()
        dummy_pred = torch.argmax(pred, dim = 1) # the prediction corresponds to the index pointing to the maximum score
        test_accuracy += (dummy_pred == y).float().sum() # sum only over correct predictions 

  test_loss = test_loss/len(test_data_loader)
  test_accuracy = 100 * test_accuracy.numpy() / size
  print("test loss =  ", test_loss, "test accuracy = ", test_accuracy)
  return X, y, dummy_pred

# %%
X, y, dummy_pred = test_loop(test_data_loader, model, loss = 'CrossEntropy')
# Out:
# test loss =   0.22097161527912898 test accuracy =  93.67

# %%
check_mistakes_last_batch(X, y, dummy_pred)
# Out:
# 1 mistakes in last batch

# %% [markdown]
# *Exercise 2: Repeat exercise n.1 with SUSY dataset.*

# %%
# download the SUSY dataset and upload it in Google Colab

import os

os.system('wget https://archive.ics.uci.edu/ml/machine-learning-databases/00279/SUSY.csv.gz')
os.system('gunzip "/content/SUSY.csv.gz"')
# Out:
# sh: wget: command not found
# gunzip: can't stat: /content/SUSY.csv.gz (/content/SUSY.csv.gz.gz): No such file or directory
# 256

# %%
# class to load the SUSY dataset

class SUSY_Dataset(torch.utils.data.Dataset):
    """SUSY pytorch dataset."""

    def __init__(self, data_file, root_dir, dataset_size, train=True, transform=None, high_level_feats=None):
        """
        This method loads the dataset from the SUSY.csv file and store the input-output pair in a tuple.
        Inputs:
            csv_file (string)= Path to the csv file with annotations.
            root_dir (string)= Directory with all the images.
            train (bool, optional)= If set to `True` load training data.
            transform (callable, optional)= Optional transform to be applied on a sample.
            high_level_festures (bool, optional): If set to `True`, working with high-level features only. 
                                        If set to `False`, working with low-level features only.
                                        Default is `None`: working with all features
        Output: data = (input,label) tuple.
        """

        import pandas as pd

        # define feature names

        features=['SUSY','lepton 1 pT', 'lepton 1 eta', 'lepton 1 phi', 'lepton 2 pT', 'lepton 2 eta', 'lepton 2 phi', 
                'missing energy magnitude', 'missing energy phi', 'MET_rel', 'axial MET', 'M_R', 'M_TR_2', 'R', 'MT2', 
                'S_R', 'M_Delta_R', 'dPhi_r_b', 'cos(theta_r1)']

        low_features=['lepton 1 pT', 'lepton 1 eta', 'lepton 1 phi', 'lepton 2 pT', 'lepton 2 eta', 'lepton 2 phi', 
                'missing energy magnitude', 'missing energy phi']

        high_features=['MET_rel', 'axial MET', 'M_R', 'M_TR_2', 'R', 'MT2','S_R', 'M_Delta_R', 'dPhi_r_b', 'cos(theta_r1)']


        # read the content of the SUSY.csv file through Pandas

        df = pd.read_csv(root_dir+data_file, header=None,nrows=dataset_size,engine='python')
        df.columns=features # assign columns names according to features names
        Y = df['SUSY'] # assign labels
        X = df[[col for col in df.columns if col!="SUSY"]] # assign inputs

        # set training and test data size
        train_size=int(0.8*dataset_size)
        self.train=train

        # train/test split
        if self.train:
            X=X[:train_size]
            Y=Y[:train_size]
            print("Training on {} examples".format(train_size))
        else:
            X=X[train_size:]
            Y=Y[train_size:]
            print("Testing on {} examples".format(dataset_size-train_size))


        self.root_dir = root_dir
        self.transform = transform

        # decides which features to use
        if high_level_feats is None:
            self.data=(X.values.astype(np.float32),Y.values.astype(int))
            print("Using both high and low level features")
        elif high_level_feats is True:
            self.data=(X[high_features].values.astype(np.float32),Y.values.astype(int))
            print("Using both high-level features only.")
        elif high_level_feats is False:
            self.data=(X[low_features].values.astype(np.float32),Y.values.astype(int))
            print("Using both low-level features only.")



    def __len__(self): # method to compute the length of the dataset
        return len(self.data[1])

    def __getitem__(self, idx): # method to iterate over examples in the dataset

        sample=(self.data[0][idx,...],self.data[1][idx])

        if self.transform: # decide whether to apply transformations to the dataset or not
            sample=self.transform(sample)

        return sample

# %%
# Use the SUSY dataset class to load data in a format suitable to PyTorch

training_data = SUSY_Dataset(
    data_file='SUSY.csv',
    root_dir='./',
    dataset_size=70000,
    train=True,
    high_level_feats=None
    )

test_data = SUSY_Dataset(
    data_file='SUSY.csv',
    root_dir='./',
    dataset_size=70000,
    train=False,
    high_level_feats=None
    )
# Out:
# Training on 56000 examples
# Using both high and low level features
# Testing on 14000 examples
# Using both high and low level features

# %%
# create a Python iterable to prepare the dataset for training and testing through the torch.utils.data class

train_data_loader = DataLoader(training_data, batch_size=100, shuffle=True)
test_data_loader = DataLoader(test_data, batch_size=100)

# %%
# extract the size of training and test set
train_set_shape = train_data_loader.dataset.data[0].shape
print("The size of the training set is = ", train_set_shape)

test_set_shape = test_data_loader.dataset.data[0].shape
print("The size of the training set is = ", test_set_shape)
# Out:
# The size of the training set is =  (56000, 18)
# The size of the training set is =  (14000, 18)

# %%
# define the neural network model
input_size = train_data_loader.dataset.data[0].shape[1]
hidden_layers = [128,64]
output_size = 2

# instantiate the sequential contrainer to stack the network layers
model = nn.Sequential( 
    nn.Linear(input_size, hidden_layers[0]),
    nn.ReLU(),
    nn.Linear(hidden_layers[0], hidden_layers[1]),
    nn.ReLU(),
    nn.Linear(hidden_layers[1], output_size)
)

# define the hyper-parameters of the network training

epochs = 5
learning_rate = 0.01
optimizer = 'SGD'
loss = 'CrossEntropy'

train_loop(train_data_loader, model, epochs = epochs, learning_rate = learning_rate, optimizer = optimizer, loss = loss)
# Out:
# Epoch 1
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.697677, running accuracy: 0.560000 [  100/56000]
# Processing batch n. 101 ----> running loss: 0.683988, running accuracy: 0.577624 [10100/56000]
# Processing batch n. 201 ----> running loss: 0.670646, running accuracy: 0.626915 [20100/56000]
# Processing batch n. 301 ----> running loss: 0.656546, running accuracy: 0.660066 [30100/56000]
# Processing batch n. 401 ----> running loss: 0.643475, running accuracy: 0.677007 [40100/56000]
# Processing batch n. 501 ----> running loss: 0.630401, running accuracy: 0.690259 [50100/56000]
#
# running training loss =   0.6224585093557835  running training accuracy =  69.68571428571428
#
# Epoch 2
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.558923, running accuracy: 0.770000 [  100/56000]
# Processing batch n. 101 ----> running loss: 0.545618, running accuracy: 0.744455 [10100/56000]
# Processing batch n. 201 ----> running loss: 0.534633, running accuracy: 0.749652 [20100/56000]
# Processing batch n. 301 ----> running loss: 0.526421, running accuracy: 0.754684 [30100/56000]
# Processing batch n. 401 ----> running loss: 0.519296, running accuracy: 0.759277 [40100/56000]
# Processing batch n. 501 ----> running loss: 0.514273, running accuracy: 0.761417 [50100/56000]
#
# running training loss =   0.510742994078568  running training accuracy =  76.27321428571429
#
# Epoch 3
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.471301, running accuracy: 0.790000 [  100/56000]
# Processing batch n. 101 ----> running loss: 0.485996, running accuracy: 0.771485 [10100/56000]
# Processing batch n. 201 ----> running loss: 0.478138, running accuracy: 0.775224 [20100/56000]
# Processing batch n. 301 ----> running loss: 0.474687, running accuracy: 0.778605 [30100/56000]
# Processing batch n. 401 ----> running loss: 0.472286, running accuracy: 0.780873 [40100/56000]
# Processing batch n. 501 ----> running loss: 0.470898, running accuracy: 0.782096 [50100/56000]
#
# running training loss =   0.47099774543728146  running training accuracy =  78.17857142857143
#
# Epoch 4
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.367519, running accuracy: 0.850000 [  100/56000]
# Processing batch n. 101 ----> running loss: 0.458064, running accuracy: 0.783762 [10100/56000]
# Processing batch n. 201 ----> running loss: 0.459970, running accuracy: 0.784378 [20100/56000]
# Processing batch n. 301 ----> running loss: 0.459969, running accuracy: 0.786312 [30100/56000]
# Processing batch n. 401 ----> running loss: 0.460264, running accuracy: 0.786185 [40100/56000]
# Processing batch n. 501 ----> running loss: 0.458992, running accuracy: 0.787665 [50100/56000]
#
# running training loss =   0.4588785240160567  running training accuracy =  78.78214285714286
#
# Epoch 5
# -------------------------------
# Processing batch n. 1 ----> running loss: 0.442725, running accuracy: 0.760000 [  100/56000]
# Processing batch n. 101 ----> running loss: 0.454377, running accuracy: 0.788515 [10100/56000]
# Processing batch n. 201 ----> running loss: 0.454348, running accuracy: 0.790149 [20100/56000]
# Processing batch n. 301 ----> running loss: 0.452292, running accuracy: 0.790598 [30100/56000]
# Processing batch n. 401 ----> running loss: 0.451411, running accuracy: 0.790923 [40100/56000]
# Processing batch n. 501 ----> running loss: 0.452438, running accuracy: 0.790878 [50100/56000]
#
# running training loss =   0.45400459436433654  running training accuracy =  78.94285714285714
#
# Done!

# %%
# Plote the training loss as a function of the number of epochs

fig, ax = plt.subplots(figsize=(10,7)) # initialize an empty figure and axes object
res = pd.read_csv("./metrics_over_epochs.csv") # read the content of the *.csv file

res.plot(x='epoch',
         y='train_loss',
         color = 'blue',
         lw = 3, # linewidth
         ax=ax) # plot the results with matplotlib through pandas

ax.set_title("train loss function versus number of epochs") # set the plot title
ax.set_ylabel("train loss") # set the name of the y axis
ax.set_xlabel("epoch") # set the name of the x axis
# Out:
# Text(0.5, 0, 'epoch')

# %%
# Plot the train accuracy as a function of the number of epochs

fig, ax = plt.subplots(figsize=(10,7)) # initialize an empty figure and axes object
res = pd.read_csv("./metrics_over_epochs.csv") # read the content of the *.csv file

res.plot(x='epoch',
         y='train_accuracy',
         color = 'red',
         lw = 3, # linewidth
         ax=ax) # plot the results with matplotlib through pandas

ax.set_title("train accuracy versus number of epochs") # set the plot title
ax.set_ylabel("train accuracy") # set the name of the y axis
ax.set_xlabel("epoch") # set the name of the x axis
# Out:
# Text(0.5, 0, 'epoch')

# %%
# compute the metrics on the test set

_ = test_loop(test_data_loader, model, loss = 'CrossEntropy')
# Out:
# test loss =   0.45101826936006545 test accuracy =  79.13571428571429
