# %%
import torch
from torch import nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Training on Images with a CNN

# %%
# Dataset

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

training_data = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=transform
)

test_data = ### YOUR CODE ###

batch_size = ### YOUR CODE ###

train_dataloader = ### YOUR CODE ###
test_dataloader = ### YOUR CODE ###

# %%
# Plot some images

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

def imshow(img):
    img = img / 2 + 0.5 # Unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(train_dataloader)
images, labels = dataiter.next()

imshow(torchvision.utils.make_grid(images))
print([classes[labels[j]] for j in range(batch_size)])

# %%
# Dataset shape

images.shape

# %%
imshow(images[2])

# %%
# Red channel

im_red = images[2].clone()
im_red[1:3,:,:] = 0.
imshow(im_red)

# %%
# Convolutional model

model = ### YOUR CODE ###

# %%
# Training

model = ### YOUR CODE ###

loss_fn = ### YOUR CODE ###

learning_rate = ### YOUR CODE ###
optimizer = ### YOUR CODE ###

epochs = ### YOUR CODE ###

for epoch in range(epochs):

    ### YOUR CODE ###

# %%
# Inference

with torch.no_grad():

    for data in test_dataloader:

        ### YOUR CODE ###

# %%
# Training with momentum, i.e. use your previous learning loop, but change the optimizer parameters

### YOUR CODE ###

# %%
# Inference (as before)

### YOUR CODE ###

# %% [markdown]
# ## Extracting Features

# %%
from torchvision.models.feature_extraction import get_graph_node_names

nodes, _ = get_graph_node_names(model)
print(nodes)

# %%
from torchvision.models.feature_extraction import create_feature_extractor

feature_extractor = create_feature_extractor(
	model, return_nodes=['conv1', 'relu', 'pool'])

# %%
image = ### YOUR CODE ###

out = feature_extractor(image)

# %%
print('conv1')
for i in range(6):
    plt.imshow(out['conv1'][0,i].detach())
    plt.show()

print('relu')
for i in range(6):
    plt.imshow(out['relu'][0,i].detach())
    plt.show()

print('pool')
for i in range(6):
    plt.imshow(out['pool'][0,i].detach())
    plt.show()
